# %% [markdown]
# # Day 1 - First Steps

# %% [markdown]
# ## **Creating Comments**

# %%
# I'm a one line comment 

''' soy un
comentario de varias lineas '''
# Out:
# ' soy un\ncomentario de varias lineas '

# %% [markdown]
# **Declaración de variables**

# %% [markdown]
# Declaramos las primeras variables, siguiendo la convención

# %%
#Asigna a la variable "nombre" tu nombre
nombre = 'Luis'
#Asigna a la variable "edad" tu edad
edad = 27
#Imprime la variable "nombre"
print(nombre)
#Imrpime la variable "edad"
print(edad)
# Out:
# Luis
# 27

# %% [markdown]
# Declaramos las primeras variables, sin seguir la conveción

# %%
#Asigna a la variable "Nombre" el nombre de un/a amigo/a
Nombre = 'Jose'
#Asigna a la variable "Edad" la edad de tu amigo/a
Edad = '28'
#Imprime la variable "Nombre"
print(Nombre)
#Imrpime la variable "Edad"
print(Edad)
# Out:
# Jose
# 28

# %% [markdown]
# ¿Qué pasa si imprimo las variables "nombre" y "Nombre", tendran los mismos valores?

# %%
#Imprime la variable "nombre"
print(nombre)
#Imprime la variable "Nombre"
print(Nombre)
# Out:
# Luis
# Jose

# %% [markdown]
# **Tipos de datos**

# %% [markdown]
# Creamos las variables int, float, str, bool

# %%
#Crea una variable "entero" y asignale un valor int
entero = 2
#Crea una variable "decimal" y asignale un valor float
decimal = 2.6
#Crea una variable "boleano" y asignale un valor bool
booleano = True
#Crea una variable "texto" y asignale un valor str
texto = 'hi how are you'

# %% [markdown]
# Comprobemos el tipo de dato de cada variable.
# Para eso podemos usar la función type(var)

# %%
#Comprobamos el tipo de dato de la variable "entero"
type(entero)
# Out:
# int

# %%
#Comprobamos el tipo de dato de la variable "decimal"
type(decimal)
# Out:
# float

# %%
#Comprobamos el tipo de dato de la variable "boleano"
type(booleano)
# Out:
# bool

# %%
#Comprobamos el tipo de dato de la variable "texto"
type(texto)
# Out:
# str

# %% [markdown]
# Casteemos algunas variables

# %%
#Casteemos la variable decimal al tipo de dato int
decimal = int(decimal)
#Verificamos nuevamente el tipo de dato ¿Qué tipo de dato tiene?
type(decimal)
# Out:
# int

# %%
#Casteemos la variable entero al tipo de dato str
entero = str(entero)
#Verificamos nuevamente el tipo de dato ¿Qué tipo de dato tiene?
type(entero)
# Out:
# str

# %% [markdown]
# Veamos que podemos hacer con las variables del tipo ***str***

# %%
#Que pasa si necesito imprimir una dirección que contenga apostrofe. Ejemplo O'leary
#Crea una variable "direccion" que contenga el valor "La dirección es O'leary esq. Oliva"
direccion = "La dirección es O'leary esq. Oliva"
#Imprime la variable
print(direccion)
# Out:
# La dirección es O'leary esq. Oliva

# %%
#Imprime una varible que tenga salto de lineas
texto = 'backslack\nejjw'
print(texto)
# Out:
# backslack
# ejjw

# %% [markdown]
# ## ***BONUS***

# %% [markdown]
# ¿Cómo puedo crear varias variables con el mismo valor?

# %%
#Asigna el valor 1 a las variables var_1,var_2 y var_3
var_1 = var_2 = var_3 = 1

# %% [markdown]
# ¿Cómo puedo crear dos variables diferentes con valores diferentes en una sola linea de código?

# %%
#Crea las variables v_1 y v_2 y asignales los valores 5 y "José"
width, height = 4, 5
print(width, height)
# Out:
# 4 5

# %% [markdown]
# **String Slicing**

# %%
#creamos la variable "curso" y le asignamos el valor "De Excel a Python"

# %%
#Extracción de la palabra "Excel"

# %%
#Extracción de la palabra "Python"

# %%
#Extración de la última letra

# %%
#Convierte el texto thonPy a Python

# %% [markdown]
# # Operadores

# %% [markdown]
# ## Aritméticos

# %%
#Crea dos variables "a" y "b" y asignales los valores 5 y 2 respectivamente

# %%
#Suma las variables

# %%
#Resta las variables

# %%
#Multiplica las variables

# %%
#Divide a entre b

# %%
#División entera de las variables

# %%
#Resto de la división

# %%
#Potencia

# %% [markdown]
# ## Asignación

# %%
#Crea una variable "a" y asignale el valor 1

# %%
#Suma en asignación

# %%
#Resta en asignación

# %%
#Multiplación en asignación

# %%
#División en asignación

# %%
#Resto en asignación

# %%
#División entera en asignación

# %%
#Potencia en asingación

# %% [markdown]
# ## Comparación

# %%
#Declara dos variables "a" y "b" y asignales los valores 10 y 25 respectivamente

# %%
#Comprueba si "a" es menor que "b"

# %%
#Comprueba si "a" es menor o igual que "b"

# %%
#Comprueba si "a" es mayor que "b"

# %%
#Comprueba si "a" es mayor o igual que "b"

# %%
#Comprueba si "a" y "b" son iguales

# %%
#Comprueba si "a" y "b" son diferentes

# %% [markdown]
# ## Lógicos

# %%
#Crea 3 variables "a","b" y "c" y asignales los valores True, True y False respectivamente

# %%
#Comprueba los valores de "a" y "b"

# %%
#Comprueba los valores de "a" o "c"

# %%
#Niega el valor de "c"

# %% [markdown]
# ## Pertenencia

# %%
#Crea dos variables "texto" y "frase" y asignales los siguientes valores "Python" y "Python for Data Science" respectivamente

# %%
#Comprueba si el texto pertenece a la frase

# %%
#Comprueba si el texto no pertenece a la frase

# %% [markdown]
# # Ejercicios

# %% [markdown]
# 1. Imprimir en pantalla "Hola Mundo"

# %% [markdown]
# 2. Crea una variable con tu nombre y luego imprime un mensaje de bienvenida
# con el nombre de usuario. Bienvenido 'nombre'

# %% [markdown]
# 3.  Calcula el indice de masa corporal de un usuario:
# > 1. Crea dos variables "peso" y "altura", asigna valores a cada una
# > 2. Crea una variable llamada "imc" que debe almacenar el indice de masa corporal.
# > 3. Imprime eel siguiente mensaje: El índice de masa corporal es "imc"
#
# ***La formula de imc es: (Peso/Altura al cuadradro)***

# %% [markdown]
# 5. Crea dos variables "a" y "b", asignales los valores "Python" vs "python" respectivamente, por último verifica si los valores son iguales

# %% [markdown]
# 6. Crea dos variables "n" y "m" asingnales dos valores enteros:
#
#
# > Muestra en  pantalla el siguiente mensaje: "n" entre m" da un cociente "c" y un resto "r".
#
# > Donde "n" y "m" son los números introducidos por el usuario, y "c" y "r" son el cociente y el resto de la división entera respectivamente.

# %% [markdown]
# 7. Crea tres variables a, b, c, asignales los valores 10,15 y 20 respectivamente luego realiza la siguiente comprobación ((a<b) and (c<b))
